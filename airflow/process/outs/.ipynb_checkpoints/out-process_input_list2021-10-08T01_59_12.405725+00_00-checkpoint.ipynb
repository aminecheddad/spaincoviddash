# %%
import pandas as pd
import os 
import sqlalchemy

# %%
with open("/home/kali/COVID-19-ES/airflow/process/input_config.txt") as f:
    input_file=f.readline()
print("will process:",input_file)
# Out:
# will process: /home/kali/COVID-19-ES/airflow/download_file/downloads/Informe_Comunicacion_20211007.ods

# %%
#Here we load the excel file download for the official web site the health ministry
#Remove the 3 last lines Total, vaccins of Armed forces and Health professionals
dataframe = pd.read_excel(input_file, sheet_name='Comunicación').iloc[:-3]
dataframe
# Out:
#             Unnamed: 0  Dosis entregadas Pfizer (1)  \
# 0            Andalucía                      9434970
# 1               Aragón                      1531845
# 2            Asturias                       1224725
# 3             Baleares                      1272150
# 4             Canarias                      2358690
# 5            Cantabria                       727305
# 6     Castilla y Leon                       2916525
# 7   Castilla La Mancha                      2330505
# 8             Cataluña                      8368460
# 9        C. Valenciana                      5797540
# 10         Extremadura                      1226825
# 11             Galicia                      3155029
# 12            La Rioja                       374465
# 13              Madrid                      7637679
# 14             Murcia                       1687865
# 15             Navarra                       734325
# 16          País Vasco                      2597220
# 17               Ceuta                        95580
# 18             Melilla                        96750
#
#     Dosis entregadas Moderna (1)  Dosis entregadas AstraZeneca (1)  \
# 0                        2019500                           1528900
# 1                         275200                            265100
# 2                         162000                            220900
# 3                         305100                            256400
# 4                         574700                            455800
# 5                         114900                            125200
# 6                         412400                            481200
# 7                         446800                            394900
# 8                        1604900                           1514300
# 9                        1213650                            863900
# 10                        218200                            186000
# 11                        507400                            573400
# 12                         67600                             53300
# 13                       1645800                           1220900
# 14                        398000                            253010
# 15                        151500                            136600
# 16                        526100                            444200
# 17                         22400                             18100
# 18                         23500                             15100
#
#     Dosis entregadas Janssen (1)  Total Dosis entregadas (1)  \
# 0                         333500                    13316870
# 1                          64700                     2136845
# 2                          43000                     1650625
# 3                          57600                     1891250
# 4                         133650                     3522840
# 5                          24950                      992355
# 6                         102200                     3912325
# 7                          95075                     3267280
# 8                         375750                    11863410
# 9                         213450                     8088540
# 10                         51750                     1682775
# 11                        122700                     4358529
# 12                         15200                      510565
# 13                        321450                    10825829
# 14                         68300                     2407175
# 15                         23750                     1046175
# 16                        101300                     3668820
# 17                          4150                      140230
# 18                          5750                      141100
#
#     Dosis administradas (2)  % sobre entregadas  \
# 0                  12759527            0.958148
# 1                   1988817            0.930726
# 2                   1664448            1.008374
# 3                   1586235            0.838723
# 4                   3124143            0.886825
# 5                    912891            0.919924
# 6                   3747347            0.957831
# 7                   3000638            0.918390
# 8                  11020265            0.928929
# 9                   7603661            0.940054
# 10                  1696943            1.008419
# 11                  4389596            1.007128
# 12                   475846            0.931999
# 13                  9757303            0.901298
# 14                  2206238            0.916526
# 15                   973795            0.930815
# 16                  3345719            0.911933
# 17                   112696            0.803651
# 18                   100956            0.715493
#
#     Nº Personas con al menos 1 dosis  Nº Personas vacunadas(pauta completada)  \
# 0                            6799161                                  6615499
# 1                            1061556                                  1038894
# 2                             871869                                   860740
# 3                             849656                                   829982
# 4                            1664938                                  1618781
# 5                             480112                                   471360
# 6                            1993845                                  1950069
# 7                            1610141                                  1544308
# 8                            5913965                                  5747628
# 9                            4055486                                  3974880
# 10                            894208                                   877847
# 11                           2302746                                  2273343
# 12                            257831                                   252187
# 13                           5294332                                  5149633
# 14                           1182330                                  1144953
# 15                            524235                                   514086
# 16                           1800058                                  1764638
# 17                             61811                                    58400
# 18                             56730                                    54040
#
#     Nº Personas con dosis adicional Fecha de la última vacuna registrada (2)
# 0                             43990                      2021-10-06 00:00:00
# 1                             14312                      2021-10-06 00:00:00
# 2                              5629                      2021-10-06 00:00:00
# 3                                 0                      2021-10-06 00:00:00
# 4                              9505                      2021-10-06 00:00:00
# 5                              5045                      2021-10-06 00:00:00
# 6                             29179                      2021-10-06 00:00:00
# 7                             12866                      2021-10-06 00:00:00
# 8                             51666                      2021-10-06 00:00:00
# 9                             27663                      2021-10-06 00:00:00
# 10                            13702                      2021-10-06 00:00:00
# 11                            22707                      2021-10-06 00:00:00
# 12                             1073                      2021-10-06 00:00:00
# 13                            27568                      2021-10-06 00:00:00
# 14                             3261                      2021-10-06 00:00:00
# 15                             3008                      2021-10-06 00:00:00
# 16                            10908                      2021-10-06 00:00:00
# 17                              408                      2021-10-06 00:00:00
# 18                                0                      2021-10-06 00:00:00

# %%
cols_names_dict = {'Unnamed: 0': 'community',
             'Dosis entregadas Pfizer (1)': 'Pfizer delivered doses',
             'Dosis entregadas Moderna (1)': 'Moderna delivered doses',
             'Dosis entregadas AstraZeneca (1)': 'AstraZeneca delivered doses',
             'Dosis entregadas Janssen (1)': 'Janssen delivered doses',
             'Total Dosis entregadas (1)': 'Total doses delivered',
             'Dosis administradas (2)': 'Doses administered',
             '% sobre entregadas': '% over delivered',
             'Nº Personas con al menos 1 dosis': 'No. People with at least 1 dose',
             'Fecha de la última vacuna registrada (2)': 'No. People vaccinated',
             'Fecha de la última vacuna registrada (2)': 'Date'}

# %%
#rename columns
dataframe.rename(columns=cols_names_dict, inplace=True)
dataframe
# Out:
#              community  Pfizer delivered doses  Moderna delivered doses  \
# 0            Andalucía                 9434970                  2019500
# 1               Aragón                 1531845                   275200
# 2            Asturias                  1224725                   162000
# 3             Baleares                 1272150                   305100
# 4             Canarias                 2358690                   574700
# 5            Cantabria                  727305                   114900
# 6     Castilla y Leon                  2916525                   412400
# 7   Castilla La Mancha                 2330505                   446800
# 8             Cataluña                 8368460                  1604900
# 9        C. Valenciana                 5797540                  1213650
# 10         Extremadura                 1226825                   218200
# 11             Galicia                 3155029                   507400
# 12            La Rioja                  374465                    67600
# 13              Madrid                 7637679                  1645800
# 14             Murcia                  1687865                   398000
# 15             Navarra                  734325                   151500
# 16          País Vasco                 2597220                   526100
# 17               Ceuta                   95580                    22400
# 18             Melilla                   96750                    23500
#
#     AstraZeneca delivered doses  Janssen delivered doses  \
# 0                       1528900                   333500
# 1                        265100                    64700
# 2                        220900                    43000
# 3                        256400                    57600
# 4                        455800                   133650
# 5                        125200                    24950
# 6                        481200                   102200
# 7                        394900                    95075
# 8                       1514300                   375750
# 9                        863900                   213450
# 10                       186000                    51750
# 11                       573400                   122700
# 12                        53300                    15200
# 13                      1220900                   321450
# 14                       253010                    68300
# 15                       136600                    23750
# 16                       444200                   101300
# 17                        18100                     4150
# 18                        15100                     5750
#
#     Total doses delivered  Doses administered  % over delivered  \
# 0                13316870            12759527          0.958148
# 1                 2136845             1988817          0.930726
# 2                 1650625             1664448          1.008374
# 3                 1891250             1586235          0.838723
# 4                 3522840             3124143          0.886825
# 5                  992355              912891          0.919924
# 6                 3912325             3747347          0.957831
# 7                 3267280             3000638          0.918390
# 8                11863410            11020265          0.928929
# 9                 8088540             7603661          0.940054
# 10                1682775             1696943          1.008419
# 11                4358529             4389596          1.007128
# 12                 510565              475846          0.931999
# 13               10825829             9757303          0.901298
# 14                2407175             2206238          0.916526
# 15                1046175              973795          0.930815
# 16                3668820             3345719          0.911933
# 17                 140230              112696          0.803651
# 18                 141100              100956          0.715493
#
#     No. People with at least 1 dose  Nº Personas vacunadas(pauta completada)  \
# 0                           6799161                                  6615499
# 1                           1061556                                  1038894
# 2                            871869                                   860740
# 3                            849656                                   829982
# 4                           1664938                                  1618781
# 5                            480112                                   471360
# 6                           1993845                                  1950069
# 7                           1610141                                  1544308
# 8                           5913965                                  5747628
# 9                           4055486                                  3974880
# 10                           894208                                   877847
# 11                          2302746                                  2273343
# 12                           257831                                   252187
# 13                          5294332                                  5149633
# 14                          1182330                                  1144953
# 15                           524235                                   514086
# 16                          1800058                                  1764638
# 17                            61811                                    58400
# 18                            56730                                    54040
#
#     Nº Personas con dosis adicional                 Date
# 0                             43990  2021-10-06 00:00:00
# 1                             14312  2021-10-06 00:00:00
# 2                              5629  2021-10-06 00:00:00
# 3                                 0  2021-10-06 00:00:00
# 4                              9505  2021-10-06 00:00:00
# 5                              5045  2021-10-06 00:00:00
# 6                             29179  2021-10-06 00:00:00
# 7                             12866  2021-10-06 00:00:00
# 8                             51666  2021-10-06 00:00:00
# 9                             27663  2021-10-06 00:00:00
# 10                            13702  2021-10-06 00:00:00
# 11                            22707  2021-10-06 00:00:00
# 12                             1073  2021-10-06 00:00:00
# 13                            27568  2021-10-06 00:00:00
# 14                             3261  2021-10-06 00:00:00
# 15                             3008  2021-10-06 00:00:00
# 16                            10908  2021-10-06 00:00:00
# 17                              408  2021-10-06 00:00:00
# 18                                0  2021-10-06 00:00:00

# %%
#Add ccaa_iso columns (iso code of communities)
def format_community(community_name) : 
    communities = {
        "Andalucía": "AN" ,
        "Aragón": "AR",
        "Asturias": "AS",
        "Canarias": "CN",
        "Cantabria": "CB",
        "Castilla y Leon": "CL",
        "Castilla La Mancha": "CM",
        "Cataluña": "CT",
        "Extremadura": "EX",
        "Galicia": "GA",
        "Baleares": "IB",
        "La Rioja": "RI",
        "Madrid": "MD",
        "Murcia": "MC",
        "Navarra": "NC",
        "País Vasco" : "PV",
        "C. Valenciana": "VC",
        "Ceuta": "CE", 
        "Melilla" : "ML"
    }
    return communities[community_name.strip()] if community_name.strip() in list(communities.keys()) else community_name

dataframe["ccaa_iso"] = dataframe["community"].apply(format_community)
#Set index to date
dataframe = dataframe.set_index("Date")
dataframe
# Out:
#                      community  Pfizer delivered doses  \
# Date
# 2021-10-06           Andalucía                 9434970
# 2021-10-06              Aragón                 1531845
# 2021-10-06           Asturias                  1224725
# 2021-10-06            Baleares                 1272150
# 2021-10-06            Canarias                 2358690
# 2021-10-06           Cantabria                  727305
# 2021-10-06    Castilla y Leon                  2916525
# 2021-10-06  Castilla La Mancha                 2330505
# 2021-10-06            Cataluña                 8368460
# 2021-10-06       C. Valenciana                 5797540
# 2021-10-06         Extremadura                 1226825
# 2021-10-06             Galicia                 3155029
# 2021-10-06            La Rioja                  374465
# 2021-10-06              Madrid                 7637679
# 2021-10-06             Murcia                  1687865
# 2021-10-06             Navarra                  734325
# 2021-10-06          País Vasco                 2597220
# 2021-10-06               Ceuta                   95580
# 2021-10-06             Melilla                   96750
#
#             Moderna delivered doses  AstraZeneca delivered doses  \
# Date
# 2021-10-06                  2019500                      1528900
# 2021-10-06                   275200                       265100
# 2021-10-06                   162000                       220900
# 2021-10-06                   305100                       256400
# 2021-10-06                   574700                       455800
# 2021-10-06                   114900                       125200
# 2021-10-06                   412400                       481200
# 2021-10-06                   446800                       394900
# 2021-10-06                  1604900                      1514300
# 2021-10-06                  1213650                       863900
# 2021-10-06                   218200                       186000
# 2021-10-06                   507400                       573400
# 2021-10-06                    67600                        53300
# 2021-10-06                  1645800                      1220900
# 2021-10-06                   398000                       253010
# 2021-10-06                   151500                       136600
# 2021-10-06                   526100                       444200
# 2021-10-06                    22400                        18100
# 2021-10-06                    23500                        15100
#
#             Janssen delivered doses  Total doses delivered  \
# Date
# 2021-10-06                   333500               13316870
# 2021-10-06                    64700                2136845
# 2021-10-06                    43000                1650625
# 2021-10-06                    57600                1891250
# 2021-10-06                   133650                3522840
# 2021-10-06                    24950                 992355
# 2021-10-06                   102200                3912325
# 2021-10-06                    95075                3267280
# 2021-10-06                   375750               11863410
# 2021-10-06                   213450                8088540
# 2021-10-06                    51750                1682775
# 2021-10-06                   122700                4358529
# 2021-10-06                    15200                 510565
# 2021-10-06                   321450               10825829
# 2021-10-06                    68300                2407175
# 2021-10-06                    23750                1046175
# 2021-10-06                   101300                3668820
# 2021-10-06                     4150                 140230
# 2021-10-06                     5750                 141100
#
#             Doses administered  % over delivered  \
# Date
# 2021-10-06            12759527          0.958148
# 2021-10-06             1988817          0.930726
# 2021-10-06             1664448          1.008374
# 2021-10-06             1586235          0.838723
# 2021-10-06             3124143          0.886825
# 2021-10-06              912891          0.919924
# 2021-10-06             3747347          0.957831
# 2021-10-06             3000638          0.918390
# 2021-10-06            11020265          0.928929
# 2021-10-06             7603661          0.940054
# 2021-10-06             1696943          1.008419
# 2021-10-06             4389596          1.007128
# 2021-10-06              475846          0.931999
# 2021-10-06             9757303          0.901298
# 2021-10-06             2206238          0.916526
# 2021-10-06              973795          0.930815
# 2021-10-06             3345719          0.911933
# 2021-10-06              112696          0.803651
# 2021-10-06              100956          0.715493
#
#             No. People with at least 1 dose  \
# Date
# 2021-10-06                          6799161
# 2021-10-06                          1061556
# 2021-10-06                           871869
# 2021-10-06                           849656
# 2021-10-06                          1664938
# 2021-10-06                           480112
# 2021-10-06                          1993845
# 2021-10-06                          1610141
# 2021-10-06                          5913965
# 2021-10-06                          4055486
# 2021-10-06                           894208
# 2021-10-06                          2302746
# 2021-10-06                           257831
# 2021-10-06                          5294332
# 2021-10-06                          1182330
# 2021-10-06                           524235
# 2021-10-06                          1800058
# 2021-10-06                            61811
# 2021-10-06                            56730
#
#             Nº Personas vacunadas(pauta completada)  \
# Date
# 2021-10-06                                  6615499
# 2021-10-06                                  1038894
# 2021-10-06                                   860740
# 2021-10-06                                   829982
# 2021-10-06                                  1618781
# 2021-10-06                                   471360
# 2021-10-06                                  1950069
# 2021-10-06                                  1544308
# 2021-10-06                                  5747628
# 2021-10-06                                  3974880
# 2021-10-06                                   877847
# 2021-10-06                                  2273343
# 2021-10-06                                   252187
# 2021-10-06                                  5149633
# 2021-10-06                                  1144953
# 2021-10-06                                   514086
# 2021-10-06                                  1764638
# 2021-10-06                                    58400
# 2021-10-06                                    54040
#
#             Nº Personas con dosis adicional ccaa_iso
# Date
# 2021-10-06                            43990       AN
# 2021-10-06                            14312       AR
# 2021-10-06                             5629       AS
# 2021-10-06                                0       IB
# 2021-10-06                             9505       CN
# 2021-10-06                             5045       CB
# 2021-10-06                            29179       CL
# 2021-10-06                            12866       CM
# 2021-10-06                            51666       CT
# 2021-10-06                            27663       VC
# 2021-10-06                            13702       EX
# 2021-10-06                            22707       GA
# 2021-10-06                             1073       RI
# 2021-10-06                            27568       MD
# 2021-10-06                             3261       MC
# 2021-10-06                             3008       NC
# 2021-10-06                            10908       PV
# 2021-10-06                              408       CE
# 2021-10-06                                0       ML

# %%
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://sql4434818:jp9sSCva1f@sql4.freemysqlhosting.net/sql4434818')
dataframe.to_sql(con=database_connection, name='vaccins', if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     604     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 605         cursor.executemany(statement, parameters)
#     606
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/cursor.py in executemany(self, operation, seq_params)
#     653             if stmt is not None:
# --> 654                 return self.execute(stmt)
#     655
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     489             query = query.encode('utf-8')
# --> 490         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     491
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/connection.py in _handle_result(self, packet)
#     394         elif packet[4] == 255:
# --> 395             raise errors.get_exception(packet)
#     396
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '%(Nº Personas vacunadas(pauta completada))s, 43990, 'AN'),('2021-10-06 00:00:00' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-9-c9c53b98dbca> in <module>
#       1 database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://sql4434818:jp9sSCva1f@sql4.freemysqlhosting.net/sql4434818')
# ----> 2 dataframe.to_sql(con=database_connection, name='vaccins', if_exists='append')
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2787             chunksize=chunksize,
#    2788             dtype=dtype,
# -> 2789             method=method,
#    2790         )
#    2791
#
# ~/.local/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     608         chunksize=chunksize,
#     609         dtype=dtype,
# --> 610         method=method,
#     611     )
#     612
#
# ~/.local/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1417                 raise ValueError("inf cannot be used with MySQL") from err
#    1418             else:
# -> 1419                 raise err
#    1420
#    1421         if not name.isdigit() and not name.islower():
#
# ~/.local/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1409
#    1410         try:
# -> 1411             table.insert(chunksize, method=method)
#    1412         except exc.SQLAlchemyError as err:
#    1413             # GH34431
#
# ~/.local/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     843
#     844                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845                 exec_insert(conn, keys, chunk_iter)
#     846
#     847     def _query_iterator(
#
# ~/.local/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     760         """
#     761         data = [dict(zip(keys, row)) for row in data_iter]
# --> 762         conn.execute(self.table.insert(), data)
#     763
#     764     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     603
#     604     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 605         cursor.executemany(statement, parameters)
#     606
#     607     def do_execute(self, cursor, statement, parameters, context=None):
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/cursor.py in executemany(self, operation, seq_params)
#     652             stmt = self._batch_insert(operation, seq_params)
#     653             if stmt is not None:
# --> 654                 return self.execute(stmt)
#     655
#     656         rowcnt = 0
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     549         else:
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#     553                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488         if not isinstance(query, bytes):
#     489             query = query.encode('utf-8')
# --> 490         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     491
#     492         if self._have_next_result:
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/connection.py in _handle_result(self, packet)
#     393             return self._handle_eof(packet)
#     394         elif packet[4] == 255:
# --> 395             raise errors.get_exception(packet)
#     396
#     397         # We have a text result set
#
# ProgrammingError: (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '%(Nº Personas vacunadas(pauta completada))s, 43990, 'AN'),('2021-10-06 00:00:00' at line 1
# [SQL: INSERT INTO vaccins (`Date`, community, `Pfizer delivered doses`, `Moderna delivered doses`, `AstraZeneca delivered doses`, `Janssen delivered doses`, `Total doses delivered`, `Doses administered`, `% over delivered`, `No. People with at least 1 dose`, `Nº Personas vacunadas(pauta completada)`, `Nº Personas con dosis adicional`, ccaa_iso) VALUES (%(Date)s, %(community)s, %(Pfizer delivered doses)s, %(Moderna delivered doses)s, %(AstraZeneca delivered doses)s, %(Janssen delivered doses)s, %(Total doses delivered)s, %(Doses administered)s, %(% over delivered)s, %(No. People with at least 1 dose)s, %(Nº Personas vacunadas(pauta completada))s, %(Nº Personas con dosis adicional)s, %(ccaa_iso)s)]
# [parameters: ({'Date': datetime.datetime(2021, 10, 6, 0, 0), 'community': 'Andalucía', 'Pfizer delivered doses': 9434970, 'Moderna delivered doses': 2019500, 'AstraZeneca delivered doses': 1528900, 'Janssen delivered doses': 333500, 'Total doses delivered': 13316870, 'Doses administered': 12759527, '% over delivered': 0.9581475977463173, 'No. People with at least 1 dose': 6799161, 'Nº Personas vacunadas(pauta completada)': 6615499, 'Nº Personas con dosis adicional': 43990, 'ccaa_iso': 'AN'}, {'Date': datetime.datetime(2021, 10, 6, 0, 0), 'community': 'Aragón', 'Pfizer delivered doses': 1531845, 'Moderna delivered doses': 275200, 'AstraZeneca delivered doses': 265100, 'Janssen delivered doses': 64700, 'Total doses delivered': 2136845, 'Doses administered': 1988817, '% over delivered': 0.9307259066520969, 'No. People with at least 1 dose': 1061556, 'Nº Personas vacunadas(pauta completada)': 1038894, 'Nº Personas con dosis adicional': 14312, 'ccaa_iso': 'AR'}, {'Date': datetime.datetime(2021, 10, 6, 0, 0), 'community': 'Asturias ', 'Pfizer delivered doses': 1224725, 'Moderna delivered doses': 162000, 'AstraZeneca delivered doses': 220900, 'Janssen delivered doses': 43000, 'Total doses delivered': 1650625, 'Doses administered': 1664448, '% over delivered': 1.0083744036349866, 'No. People with at least 1 dose': 871869, 'Nº Personas vacunadas(pauta completada)': 860740, 'Nº Personas con dosis adicional': 5629, 'ccaa_iso': 'AS'}, {'Date': datetime.datetime(2021, 10, 6, 0, 0), 'community': 'Baleares', 'Pfizer delivered doses': 1272150, 'Moderna delivered doses': 305100, 'AstraZeneca delivered doses': 256400, 'Janssen delivered doses': 57600, 'Total doses delivered': 1891250, 'Doses administered': 1586235, '% over delivered': 0.8387230667547918, 'No. People with at least 1 dose': 849656, 'Nº Personas vacunadas(pauta completada)': 829982, 'Nº Personas con dosis adicional': 0, 'ccaa_iso': 'IB'}, {'Date': datetime.datetime(2021, 10, 6, 0, 0), 'community': 'Canarias', 'Pfizer delivered doses': 2358690, 'Moderna delivered doses': 574700, 'AstraZeneca delivered doses': 455800, 'Janssen delivered doses': 133650, 'Total doses delivered': 3522840, 'Doses administered': 3124143, '% over delivered': 0.8868251183704057, 'No. People with at least 1 dose': 1664938, 'Nº Personas vacunadas(pauta completada)': 1618781, 'Nº Personas con dosis adicional': 9505, 'ccaa_iso': 'CN'}, {'Date': datetime.datetime(2021, 10, 6, 0, 0), 'community': 'Cantabria', 'Pfizer delivered doses': 727305, 'Moderna delivered doses': 114900, 'AstraZeneca delivered doses': 125200, 'Janssen delivered doses': 24950, 'Total doses delivered': 992355, 'Doses administered': 912891, '% over delivered': 0.9199238175854407, 'No. People with at least 1 dose': 480112, 'Nº Personas vacunadas(pauta completada)': 471360, 'Nº Personas con dosis adicional': 5045, 'ccaa_iso': 'CB'}, {'Date': datetime.datetime(2021, 10, 6, 0, 0), 'community': 'Castilla y Leon ', 'Pfizer delivered doses': 2916525, 'Moderna delivered doses': 412400, 'AstraZeneca delivered doses': 481200, 'Janssen delivered doses': 102200, 'Total doses delivered': 3912325, 'Doses administered': 3747347, '% over delivered': 0.9578312128977015, 'No. People with at least 1 dose': 1993845, 'Nº Personas vacunadas(pauta completada)': 1950069, 'Nº Personas con dosis adicional': 29179, 'ccaa_iso': 'CL'}, {'Date': datetime.datetime(2021, 10, 6, 0, 0), 'community': 'Castilla La Mancha', 'Pfizer delivered doses': 2330505, 'Moderna delivered doses': 446800, 'AstraZeneca delivered doses': 394900, 'Janssen delivered doses': 95075, 'Total doses delivered': 3267280, 'Doses administered': 3000638, '% over delivered': 0.9183902206116402, 'No. People with at least 1 dose': 1610141, 'Nº Personas vacunadas(pauta completada)': 1544308, 'Nº Personas con dosis adicional': 12866, 'ccaa_iso': 'CM'}  ... displaying 10 of 19 total bound parameter sets ...  {'Date': datetime.datetime(2021, 10, 6, 0, 0), 'community': 'Ceuta', 'Pfizer delivered doses': 95580, 'M ...
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
os.system(f'mv "{input_file}" "/home/kali/COVID-19-ES/airflow/process/processed/"')
